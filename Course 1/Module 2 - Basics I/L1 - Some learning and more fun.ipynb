# %% [markdown]
# # <center><B>1. Some learning and more fun</B></center>
# ---

# %% [markdown]
# ## Learning Goals
#
#  * Know what is syntax and codeblocks
#  * How to write code and run it in Jupyter notebook
#  * What is a string and how to define them
#  * Some cool fun facts

# %% [markdown]
# ---
# ## 1.1. Syntax and Code Blocks
#  <p align="justify">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;When coding, ensuring proper syntax is crucial. Even the smallest error, such as a missing parentheses or an extra comma, can lead to a syntax error, causing the code to fail to execute. It's important to be vigilant, as errors can occur even with seemingly insignificant mistakes. If your code produces errors or exceptions, it's essential to carefully review the syntax and be mindful of minor errors.<br><br>&nbsp;&nbsp;&nbsp;Correct syntax alone may not guarantee desired outcomes; unexpected behavior or output could stem from semantic issues as well. Syntax governs the structure of code, while semantics dictate the meaning behind coded statements. It's vital to consider what the code aims to achieve. Although code may be syntactically correct and run without errors, it may not fulfill its intended purpose.<br><br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;When tackling code blocks in this course's exercises, be attentive to syntax errors and assess the overall functionality of your code. Simply rectifying a syntax error does not guarantee the desired outcome upon execution. After addressing any errors, ensure to submit your code for evaluation and verification.</p>

# %% [markdown]
# ---
# ## 1.2. Let's create something
#
#  <p align="justify">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Programming languages are written languages, and the core of written communication is text. How is text represented in Python? How can we ask a question to a person? And how can we provide information to a person? To answer these questions, read further and don't forget to run and visualize the output as well.</p>

# %% [markdown]
# <I>Writing Text:</I>  In coding, we use the word *string* to refer to *text*. We can define strings as follows:
#  - *In Normal text* - <B>This is a string</B><br>
#  - *In Python* - <B>"This is a string"</B> or <B>'This is a string'</B>
#  - In Python and many other programming languages, anything you put between quotes (either single or double) becomes a string. Check out the Python code snippet below, where a string is defined..
#
#  ```python
#  "This is a string"
#  'This is a string'
#  # In Python, strings are written within single/double quotes
#  # Beware! Don't mix the quotes, so better stick to either '_' or "_"
#  ```
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;In the code cells below, you're going to start coding. Feel free to edit the string and try removing the quotes and check out what happens.

# %% [markdown]
# <mark>**😃 Fun Facts 😃**</mark><br>
# > * **Code Snippet** - *Code Snippets are actual codes (full/partial) which can be reused in a compiler and run. It means you can simply copy and paste it in a Jupyter cell and visualize the output.*
# > * **Comments** - *In the above snippet there is a line in green. Noticed that there is an '#' sybmol at the start? In Python, anything written after an '#' is called a comment. These lines are not executed by the compiler. It's main purpose is to improve the understandability of the code, as in the above example.*

# %%
"This is a string"
# Out:
# 'This is a string'

# %%
'This is a string'

# Try removing one or both quotes and see what happens when run.
# Something weird is being displayed?
# Don't worry, we'll get to know about those weird things later in this course.
# For now know them as Errors or Exceptions.
# Out:
# 'This is a string'

# %%
'Anything (aA,bB,...zZ; 0,1,2,3,4,...9; !@#$) you write in between quotes (either single/double) is a string'

# Notice that we can write numbers and symbols too as a string.
# Out:
# 'Anything (aA,bB,...zZ; 0,1,2,3,4,...9; !@#$) you write in between quotes (either single/double) is a string'

# %%
# MORE PRACTICE:

# This is a string
"This is a string"

# This is also a string
'This is a string'

# Strings can contain numbers and symbols too
'12345'
"!@#$%"

# Strings can be used to represent questions
'What is your name?'

# Strings can be used to represent information
'My name is John Doe'

# Jupyter output displays only the last executable statement in a cell. So don't get confused when you run this cell.
# Out:
# 'My name is John Doe'

# %% [markdown]
# <p align="justify">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;In the above cell, we learnt that the strings can be used to represent questions and information. In computational problem solving, we need to ask questions and access information from the user. And strings are handy for this purpose. This is discussed in the next lesson.</p>

# %% [markdown]
# <mark> To be added <br>
# * Exercises
# * Official documentation
