# %% [markdown]
# # <center><B>4. Basic Datatypes</B></center>
# ---

# %% [markdown]
# ## **Learning Goals**
#
#  * What is a datatype
#  * Basic datatypes in Python
#  * How to distinguish between datatypes
#  * Brief learning about Errors in Python

# %% [markdown]
# ---
# ## **4.1. You've already learnt and used datatypes!**
#
# <p align="justify">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Did you notice in the previous lesson, when we printed numbers, we didn't use the single/double quotes. We have already learnt that the strings are texts. A computer cannot logically perform arithmetic operation on strings/texts. Therefore, we do not enter number as strings rather as numbers itself, when we want to arithmetically operate on them. Here strings and numbers can be classified by their types.<br><br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;In programming terminology, a string is known as a data type, whether it's a mobile game or a script used to automatically create user accounts. Most programs need to manipulate some kind of data, and that data can come in a lot of different forms, or like we call them data types. A string is only one kind of data type found in Python. In the code snippet below, can you guess what the result would be when you run it? Datatypes are used to instruct the computer about the type of data.<br></p>
#
# ```python
# # Feel free to insert new cell and tryout these lines of code
#
# print('1')    # Prints 1 as a string
# print(1)      # Prints 1 as an integer
# print('2+3')  # Prints the string 2+3 because we instructed to computer they're string (Single quotes)
# print(2+3)    # Prints result 5 because we instructed to computer they're numbers (No quotes)
# ```
# <p align="justify">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;All programming languages offer some primary/basic datatypes and some secondary/functional datatypes that are suited for their specific purpose. In this module, we'll learn the primary datatypes offered in Python. And over the course, we'll also learn about the secondary datatypes.</p>

# %% [markdown]
# ---
# <mark>**😃 Fun Facts 😃**</mark><br>
# > * Comments can be inserted in a new line or just beside a line of code. The only requirement is that it should start with '#'. Check the snippet above again.
# > * In python strings and numbers are highlighted in different colours to improve readability.
# ---

# %% [markdown]
# ---
# ## **4.2. Datatypes in Python**
#
# <p align="justify">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Python has several built-in data types, including numeric types (int, float, complex), string (str), boolean (bool), and collection types (list, tuple, dict, set). Each data type has its own set of properties, methods, and behaviors that allow programmers to manipulate and process data effectively in their programs.

# %% [markdown]
# 1. **Numeric Data Types**: Numeric data types in Python are used to represent numerical values. Python provides three primary numeric data types:
#   * Integer ***(int)***: Integers are whole numbers without any decimal points. They can be positive or negative.
#   ```python
#     # Integer Datatype (int)
#     1
#     782
#   ```
#   * Floating-Point ***(float)***: Floating-point numbers represent decimal values. They can be positive or negative and may contain a decimal point.
#   ```python
#     # Floating Point Datatype (float)
#     125.0
#     0.1467
#   ```
#   * Complex ***(complex)***: Complex numbers are used to represent numbers with a real and imaginary part. They are written in the form of ***a + bj***, where a is the real part and b is the imaginary part.
#   ```python
#     # Complex Datatype (complex)
#     4+5j
#     3.6+7j
#   ```
# <br>
#
# 2. **String Data Type (str)**: Represents a sequence of characters enclosed in single quotes (‘ ‘) or double quotes (” “), such as “Hello, World!”, ‘Python’. We've already learnt about strings.
#
# <br>
#
# 3. **Boolean Data Type (bool)**: Represents either True or False, used for logical operations and conditions.
#     ```python
#       True
#       False
#     ```
# <br>
#
# 4. **Collection Data Types**:
#   * ***list***: Represents an ordered and mutable collection of items, enclosed in square brackets ([]).
#   ```python
#     # List Datatype (list)
#     [1,2,3,4]
#     ['a','b','c','d']
#     [1,0.6,3+6j,'Eight','9','@#$%']
#   ```
#   * ***tuple***: Represents an ordered and immutable collection of items, enclosed in parentheses ().
#   ```python
#   # Tuple Datatype (tuple)
#   (1,2,3,4)
#   ('a','b','c','d')
#   (1,0.6,3+6j,'Eight','9','@#$%')
#   ```
#   * ***dict***: Short for Dictionary. Represents a collection of key-value pairs enclosed in curly braces ({}) with unique keys.
#    ```python
#   # Dictionary Datatype (dict)
#   {'Numbers_List':[1,2,3,4],
#   'Alphabets_Tuple':('a','b','c','d'), 'One':1, 'Add':'+',
#   4:'Four'}
#   ```
#   * ***set***: Represents an unordered and mutable collection of unique elements, enclosed in curly braces ({}).
#   ```python
#     # List Datatype (list)
#     {1,2,3,4}
#     {'a','b','c','d'}
#     {1,0.6,3+6j,'Eight','9','@#$%'}
#   ```

# %% [markdown]
# ---
# ## **4.3. Spinoff about Methods & Errors in Python**
#
# * ***4.3.1. Methods:***
#   <p align="justify">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Methods are built-in functions that can be used on specific or all objects within the code. For example, <b><i>input(), print()</i></b> can be called methods in python. A method can be used across all datatypes and specific to one/several datatypes in python. We'll learn many such methods as we progress through the course.<br><br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<b><i>type()</i></b> is a methods used to identify the datatype of an object. Now let's see how it can be used. As discussed earlier, <b><i>type()</i></b>can be nested inside <b><i>print()</i></b>. Read the basic syntax given in below code snippet and run the below code cells to understand the <b><i>type()</i></b> method.
#
#   ```python
#   # Syntax for type() and type() nested in print() methods.
#   type(<item>)
#   print(type(<item>))
#   ```

# %%
# Replace the item within () with different datatypes and run the cell.
type(1)
# Out:
# int

# %%
print(type('Hi World'))
print(type(1))
print(type(2+4.0)) # Though 2 is int and 4.0 is float, result 6.0 is float, hence type(6.0) is float
print(type(3+5j+1))
print(type(True))
print(type([1,2,3,4]))
print(type((1,0.6,3+6j,'Eight','9','@#$%')))
print(type({'Numbers_List':[1,2,3,4],
'Alphabets_Tuple':('a','b','c','d'), 'One':1, 'Add':'+',
4:'Four'}))
print(type({1,2,3,4}))

# In the result you might find the datatype mentioned as <class 'datatype'>.
# Don't bother about class for now we'll definitely learn it later.
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'bool'>
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>
# <class 'set'>

# %% [markdown]
# ---
# <mark>**😃 Fun Facts 😃**</mark><br>
# > **Dictionary** - *Did you notice that dictionary is written in multiple lines in the above snippets? Yes it is acceptable while writing code in Python. Same is applicable for list, tuple and set.*
# ---

# %% [markdown]
# <br>
#
# * 4.3.2. Errors in Python:
#  <p align="justify">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Generally, your computer doesn't know how to mix different data types. For example, adding two integers together makes perfect sense to computers, like this: print(7+8) 15 Adding together two strings also makes sense: print("hello " + "world") We just end up with the longer strings that contain the two, like so: hello world but your computer doesn't know how to add an integer and a string. If you tell it to mix these two different data types: print(7 + "8") your computer isn't going to know what to do and will raise an error. Check it out: TypeError: unsupported operand type(s) for +: 'int' and "str' Oh, no, our first error, but don't panic. Errors are a common part of programming, and you'll probably have to deal with them a lot. The trick is to think of errors as little clues from your computer to help you improve your programming skills. Read the errors carefully, understand what they're telling you, and then use that new knowledge to help you fix the mistake. In this example, the last line of the error message shows us that we've encountered something called a TypeError. Then we get a bit of explanatory text, that tells us that the plus sign can't be used between an int type and an str type, which are short names for integer and string. Thinking about what we've already learned about strings, integers, and mixing data types, can you guess what the error is trying to tell us? The message unsupported operand type, tells us that we can't add the integer seven and the string eight, because they're different data types, but what if you didn't have an instructor to helpfully point that out? How would you know? You'd need to use your research skills and the resources we called out earlier in the course to do some investigating. For example, you could look for information about the error by pasting the TypeError message into the search bar of your favorite search engine. This is a common trick used by almost everyone learning to code, and even by experienced developers. You'll usually find that other people on the Internet have reported similar errors and solved them too. Back to our example. Maybe you're thinking, aren't we adding two numbers here? Looks a bit like it, right? Well, look carefully and remember that anything wrapped in quotation marks is considered a string in Python. So eight is a string here: "8" while seven is an integer. To the computer, adding seven plus eight is just as strange as adding seven plus A is to us, and seven plus A equals no sense at all.

# %% [markdown]
# ---
# ## **4.4. Let's Code:**
#
# (4a)

# %% [markdown]
# <mark> To be added <br>
# * Official documentation
